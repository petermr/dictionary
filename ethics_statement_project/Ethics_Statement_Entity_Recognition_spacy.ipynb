# %% [markdown]
# <a href="https://colab.research.google.com/github/petermr/dictionary/blob/main/ethics_statement_project/Ethics_Statement_Entity_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pathlib
import spacy 
from spacy import displacy
spacy.__version__
# Out:
# '2.2.4'

# %%
text = pathlib.Path("ethics_statement_cancer_clinical_trial_15.txt").read_text()

# %%
#Download spacy models
#!python -m spacy download en_core_web_sm

# %%
# Loading SpaCy language model small
nlp = spacy.load("en_core_web_sm")

# %%
import pandas as pd
#!python -m pip install icecream
#from icecream import ic
doc = nlp(text)

entities = []
labels = []
position_start = []
position_end = []

for ent in doc.ents:
    entities.append(ent)
    labels.append(ent.label_)
    position_start.append(ent.start_char)
    position_end.append(ent.end_char)
    
df = pd.DataFrame({'Entities':entities,'Labels':labels,'Position_Start':position_start, 'Position_End':position_end})
pd.set_option("display.max_rows", None, "display.max_columns", None)
df
#ic(entities, labels)
# Out:
#                                              Entities       Labels  \
# 0            (The, institutional, ethical, committee)          ORG
# 1                                          (Protocol)          LAW
# 2                         (Clinical, Trial, Registry)          ORG
# 3                                             (India)          GPE
# 4                                              (NIMS)          ORG
# 5                               (CTRI/2020/07/026791)       PERSON
# 6                                    (25, July, 2020)         DATE
# 7                    (the, Declaration, of, Helsinki)  WORK_OF_ART
# 8               (the, Ministry, of, Health, ,, Labor)          ORG
# 9                                           (Welfare)          GPE
# 10                                            (Japan)          GPE
# 11  (the, Ethics, Committee, of, Yokohama, City, U...          ORG
# 12                            (December, 22, ,, 2016)         DATE
# ...

# %% [markdown]
# Followed the code from https://github.com/raaga500/YTshared/blob/master/V3_NamedEntityReco_3.ipynb
