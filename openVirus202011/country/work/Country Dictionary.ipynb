# %% [markdown]
#  #  <span style="color: maroon; font-size:50px"> <b> The Country Dictionary From Scratch</b> </span>
#
#
#
#
# #### Dictionaries are made using WIKIDATA SPARQL
# The following code is about building the country dictionary first using SPARQL and then using amidict to validate

# %%
#!pip install SPARQLWrapper 
from SPARQLWrapper import SPARQLWrapper, JSON,  XML
import pandas as pd

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql", agent="Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11")

# %%
sparql.setQuery("""
## This query contains phrases common to all queries and others which are specific to particular dictionaries.(SPECIFIC) 
## Select Query was used to retrieve specific results (Country name, wiki data number, Synonyms) 

## ?code as ?_iso3166 is optional and is specific to countries 

SELECT ?wikidata ?wikidataLabel ?wikipedia (?wikidataAltLabel as ?alt) ?synonym (?wikidataLabel as ?term) ?wikidataDescription
## (SPECIFIC) links to ?wikidata below
    (?code as ?_iso3166) ?coords { 

## Forcing particular query execution order
  hint:Query hint:optimizer "None" . 

## all ISO countries (SPECIFIC) must link to ?code above. 
  # ?wikidata wdt:P297 ?code.
  # ?wikidata wdt:P625 ?coords.

## Optional details about the terms like links to wikipaedia pages for each wikipedia page to be presented in a seperate column
  OPTIONAL { ?wikipedia schema:about ?wikidata; schema:isPartOf <https://en.wikipedia.org/> }
  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "en".

## Selecting the prefered label 
    # ?wikidata skos:altLabel ?wikidataAltLabel ; rdfs:label ?wikidataLabel; schema:description  ?wikidataDescription          
  } 

## (SPECIFIC) Making sure the RGI alphabets of the flags are not rendered as flags and they appear as simple alphabets by specifying the acceptable characters. 
  BIND (REPLACE(REPLACE(?wikidataAltLabel, "(, )?[🇦-🇿]{2}", ""), "^, ", "") AS ?synonym )
      }
""")

sparql.setReturnFormat(XML)
results = sparql.query().convert()

sparql.setReturnFormat(JSON)
results1 = sparql.query().convert()

# %%
print("THE SPARL QUERY RESULT LOOKS LIKE THIS: ")
print("*******************************************")
results_df = pd.io.json.json_normalize(results1['results']['bindings'])
results_df[['wikidata.value', 'wikidataLabel.value', '_iso3166.value', 'wikipedia.value', 'alt.value', 'synonym.value', 'coords.value' , 'term.value']].head()
# Out:
# THE SPARL QUERY RESULT LOOKS LIKE THIS:
# *******************************************
#                         wikidata.value wikidataLabel.value _iso3166.value  \
# 0   http://www.wikidata.org/entity/Q16              Canada             CA
# 1  http://www.wikidata.org/entity/Q258        South Africa             ZA
# 2   http://www.wikidata.org/entity/Q55         Netherlands             NL
# 3   http://www.wikidata.org/entity/Q20              Norway             NO
# 4  http://www.wikidata.org/entity/Q265          Uzbekistan             UZ
#
#                               wikipedia.value  \
# 0        https://en.wikipedia.org/wiki/Canada
# 1  https://en.wikipedia.org/wiki/South_Africa
# 2   https://en.wikipedia.org/wiki/Netherlands
# 3        https://en.wikipedia.org/wiki/Norway
# 4    https://en.wikipedia.org/wiki/Uzbekistan
#
#                                            alt.value  \
# 0  CA, ca, CDN, can, CAN, British North America, ...
# 1     SA, za, Republic of South Africa, RSA, 🇿🇦, zaf
# 2  NL, Holland, Nederland, NED, nl, the Netherlan...
# 3  NO, Norge, no, NOR, Kingdom of Norway, 🇳🇴, Nor...
# 4                Republic of Uzbekistan, uz, 🇺🇿, UZB
#
#                                        synonym.value  \
# 0  CA, ca, CDN, can, CAN, British North America, ...
# 1         SA, za, Republic of South Africa, RSA, zaf
# 2  NL, Holland, Nederland, NED, nl, the Netherlan...
# 3  NO, Norge, no, NOR, Kingdom of Norway, Noreg, ...
# 4                    Republic of Uzbekistan, uz, UZB
#
#                coords.value    term.value
# 0        Point(-109.0 56.0)        Canada
# 1         Point(24.0 -29.0)  South Africa
# 2  Point(5.55 52.316666666)   Netherlands
# 3          Point(11.0 65.0)        Norway
# 4          Point(66.0 41.0)    Uzbekistan

# %% [markdown]
# Save the sparql endpoint in country.xml

# %%
with open("dictionary\country.sparql.xml", "w", encoding="utf-8") as f:
    f.write(results.toxml())

# %% [markdown]
# ### Installing ami
# Requirements: JDK, Maven, git

# %%
# !git clone https://github.com/petermr/ami3.git
# !cd ami3
# !mvn install -Dmaven.test.skip=true
# Out:
# fatal: destination path 'ami3' already exists and is not an empty directory.
# [INFO] Scanning for projects...
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD FAILURE
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  0.059 s
# [INFO] Finished at: 2020-12-03T08:01:06+05:30
# [INFO] ------------------------------------------------------------------------
# [ERROR] The goal you specified requires a project to execute but there is no POM in this directory (C:\Users\eless\Documents\viral_epidemic_country). Please verify you invoked Maven from the correct directory. -> [Help 1]
# [ERROR]
# [ERROR] To see the full stack trace of the errors, re-run Maven with the -e switch.
# [ERROR] Re-run Maven using the -X switch to enable full debug logging.
# [ERROR]
# [ERROR] For more information about the errors and possible solutions, please read the following articles:
# [ERROR] [Help 1] http://cwiki.apache.org/confluence/display/MAVEN/MissingProjectException

# %% [markdown]
# ##### The Results should look like this

# %% [raw]
# [...]
# [INFO] Installing C:\Users\Desktop\ami3\pom.xml to C:\Users\.m2\repository\org\contentmine\ami3\0.1-SNAPSHOT\ami3-0.1-SNAPSHOT.pom
# [INFO] Installing C:\Users\Desktop\ami3\target\ami3-0.1-SNAPSHOT-jar-with-dependencies.jar to C:\Users\.m2\repository\org\contentmine\ami3\0.1-SNAPSHOT\ami3-0.1-SNAPSHOT-jar-with-dependencies.jar
# [INFO] -------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] -------------------------------------------------------------
# [INFO] Total time: 03:21 min
# [INFO] Finished at: 2020-06-13T36+05:30
# [INFO] -------------------------------------------------------------

# %% [markdown]
# #### AMIDICT
# amidict converts the SPARQL output into the required dictionary format and also to validate it

# %%
# !amidict --help
# Out:
# Usage: amidict [OPTIONS] COMMAND
#
# `amidict` is a command suite for managing dictionary:
#
# Parameters:
# ===========
#       [@<filename>...]   One or more argument files containing options.
# Options:
# ========
#   -d, --dictionary=<dictionaryNameList>[,<dictionaryNameList>...]...
#                          input or output dictionary NAMES/s. for 'create' must be singular; when 'display' or
#                            'translate', any number. Names should be lowercase, unique. [a-z][a-z0-9._]. Dots can be
#                            used to structure dictionaries intodirectories. Dictionary names are relative to
#                            'directory'. If <directory> is absent then dictionary names are absolute. ) This doesn't
#                            make sense; it should relate to current working directory.
#       --directory=<directory>
#                          top directory containing dictionary/s. Subdirectories will use structured names (NYI). Thus
#                            dictionary 'animals' is found in '<directory>/animals.xml', while 'plants.parts' is found in
#                            <directory>/plants/parts.xml. Required for relative dictionary names.
#   -h, --help             Show this help message and exit.
#   -V, --version          Print version information and exit.
# General Options:
#   -i, --input=FILE       Input filename, containing input for dictionary. its basename becomes the inputname
#   -n, --inputname=PATH   User's basename for inputfiles (e.g. foo/bar/<basename>.txt). The default name for the
#                            dictionary;  but may be obsolete and superseded by `dictionary`
#   -L, --inputnamelist=PATH...
#                          List of inputnames; will iterate over them, essentially compressing multiple commands into
#                            one. Experimental.
#   -x, --informat=PATH    extension for dictionary file , default: xml
# Logging Options:
#   -v, --verbose          Specify multiple -v options to increase verbosity. For example, `-v -v -v` or `-vvv`. We map
#                            ERROR or WARN -> 0 (i.e. always print), INFO -> 1(-v), DEBUG->2 (-vv)
#       --log4j=(CLASS LEVEL)...
#                          Customize logging configuration. Format: <classname> <level>; sets logging level of class, e.
#                            g.
#                           org.contentmine.ami.lookups.WikipediaDictionary INFO
# Commands:
# =========
#   create     creates dictionaries from text, Wikimedia, etc..
#   display    Displays AMI dictionaries. (Under Development)
#   search     searches within dictionaries
#   translate  translates dictionaries between formats
#   update     updates or merges dictionaries

# %% [markdown]
# #### Convert SPARQL Endpoint into the Country Dictionary

# %%
# !amidict -vv --dictionary country --directory dictionary  --input dictionary/country.sparql.xml create --informat wikisparqlxml --sparqlmap name=wikidataLabel,term=wikidataLabel,description=wikidataDescription,wikidataURL=wikidata,wikidataID=wikidata,wikipediaPage=wikipedia,wikipediaURL=wikipedia,_p297_country=_iso3166,_coords=coords --transformName wikidataID=EXTRACT(wikidataURL,.*/(.*)) --synonyms=synonym
# Out:
# Generic values (DictionaryCreationTool)
# ================================
# --testString        : d      null
# --wikilinks         : d [Lorg.contentmine.ami.tools.AbstractAMIDictTool$WikiLink;@736caf7a
# --datacols          : d      null
# --hrefcols          : d      null
# --informat          : m wikisparqlxml
# --linkcol           : d      null
# --namecol           : d      null
# --outformats        : d [Lorg.contentmine.ami.tools.AbstractAMIDictTool$DictionaryFileFormat;@63798ca7
# --query             : d      null
# --sparqlmap         : m {name=wikidataLabel, term=wikidataLabel, description=wikidataDescription, wikidataURL=wikidata, wikidataID=wikidata, wikipediaPage=wikipedia, wikipediaURL=wikipedia, _p297_country=_iso3166, _coords=coords}
# --sparqlquery       : d      null
# --synonyms          : m [synonym]
# --template          : d      null
# --termcol           : d      null
# --termfile          : d      null
# --terms             : d      null
# --transformName     : m {wikidataID=EXTRACT(wikidataURL,.*/(.*))}
# --wptype            : d      null
# --input             : d      null
# --inputnamelist     : d      null
# --help              : d     false
# --version           : d     false
# --dictionary        : d [country]
# --directory         : d dictionary
#
# Specific values (DictionaryCreationTool)
# ================================
# --testString        : d      null
# --wikilinks         : d [Lorg.contentmine.ami.tools.AbstractAMIDictTool$WikiLink;@736caf7a
# --datacols          : d      null
# --hrefcols          : d      null
# --informat          : m wikisparqlxml
# --linkcol           : d      null
# --namecol           : d      null
# --outformats        : d [Lorg.contentmine.ami.tools.AbstractAMIDictTool$DictionaryFileFormat;@63798ca7
# --query             : d      null
# --sparqlmap         : m {name=wikidataLabel, term=wikidataLabel, description=wikidataDescription, wikidataURL=wikidata, wikidataID=wikidata, wikipediaPage=wikipedia, wikipediaURL=wikipedia, _p297_country=_iso3166, _coords=coords}
# --sparqlquery       : d      null
# --synonyms          : m [synonym]
# --template          : d      null
# --termcol           : d      null
# --termfile          : d      null
# --terms             : d      null
# --transformName     : m {wikidataID=EXTRACT(wikidataURL,.*/(.*))}
# --wptype            : d      null
# --input             : d      null
# --inputnamelist     : d      null
# --help              : d     false
# --version           : d     false
# --dictionary        : d [country]
# --directory         : d dictionary
# {wikidataLabel=[name, term], wikidataDescription=[description], _iso3166=[_p297_country], wikipedia=[wikipediaPage, wikipediaURL], wikidata=[wikidataURL, wikidataID], coords=[_coords]}
# <entry _coords="Point(5.55 52.316666666)" _p297_country="NL" description="country in western Europe, part of the Kingdom of the Netherlands" name="Netherlands" term="Netherlands" wikidataURL="http://www.wikidata.org/entity/Q55" wikipediaPage="https://en.wikipedia.org/wiki/Netherlands" wikipediaURL="https://en.wikipedia.org/wiki/Netherlands" wikidataID="Q55"><synonym>NL</synonym><synonym>Holland</synonym><synonym>Nederland</synonym><synonym>NED</synonym><synonym>nl</synonym><synonym>the Netherlands</synonym><synonym>Netherlands (after 1945)</synonym></entry>
# <entry _coords="Point(24.0 -29.0)" _p297_country="ZA" description="sovereign state in Southern Africa" name="South Africa" term="South Africa" wikidataURL="http://www.wikidata.org/entity/Q258" wikipediaPage="https://en.wikipedia.org/wiki/South_Africa" wikipediaURL="https://en.wikipedia.org/wiki/South_Africa" wikidataID="Q258"><synonym>SA</synonym><synonym>za</synonym><synonym>Republic of South Africa</synonym><synonym>RSA</synonym><synonym>zaf</synonym></entry>
# <entry _coords="Point(-109.0 56.0)" _p297_country="CA" description="sovereign state in North America" name="Canada" term="Canada" wikidataURL="http://www.wikidata.org/entity/Q16" wikipediaPage="https://en.wikipedia.org/wiki/Canada" wikipediaURL="https://en.wikipedia.org/wiki/Canada" wikidataID="Q16"><synonym>CA</synonym><synonym>ca</synonym><synonym>CDN</synonym><synonym>can</synonym><synonym>CAN</synonym><synonym>British North America</synonym><synonym>Dominion of Canada</synonym><synonym>Can.</synonym></entry>
# <entry _coords="Point(29.0 27.0)" _p297_country="EG" description="sovereign state in Africa and Asia" name="Egypt" term="Egypt" wikidataURL="http://www.wikidata.org/entity/Q79" wikipediaPage="https://en.wikipedia.org/wiki/Egypt" wikipediaURL="https://en.wikipedia.org/wiki/Egypt" wikidataID="Q79"><synonym>EGY</synonym><synonym>eg</synonym><synonym>Republic of Egypt</synonym><synonym>Arab Rep. Egypt</synonym><synonym>Arab Republic of Egypt</synonym><synonym>Rep. Egypt</synonym></entry>
# <entry _coords="Point(11.0 65.0)" _p297_country="NO" description="sovereign state in northern Europe" name="Norway" term="Norway" wikidataURL="http://www.wikidata.org/entity/Q20" wikipediaPage="https://en.wikipedia.org/wiki/Norway" wikipediaURL="https://en.wikipedia.org/wiki/Norway" wikidataID="Q20"><synonym>NO</synonym><synonym>Norge</synonym><synonym>no</synonym><synonym>NOR</synonym><synonym>Kingdom of Norway</synonym><synonym>Noreg</synonym><synonym>Norvège</synonym><synonym>Norwegen</synonym></entry>
# <entry _coords="Point(66.0 41.0)" _p297_country="UZ" description="sovereign state in Central Asia" name="Uzbekistan" term="Uzbekistan" wikidataURL="http://www.wikidata.org/entity/Q265" wikipediaPage="https://en.wikipedia.org/wiki/Uzbekistan" wikipediaURL="https://en.wikipedia.org/wiki/Uzbekistan" wikidataID="Q265"><synonym>Republic of Uzbekistan</synonym><synonym>uz</synonym><synonym>UZB</synonym></entry>
# <entry _coords="Point(-71.0 -33.0)" _p297_country="CL" description="sovereign state in South America" name="Chile" term="Chile" wikidataURL="http://www.wikidata.org/entity/Q298" wikipediaPage="https://en.wikipedia.org/wiki/Chile" wikipediaURL="https://en.wikipedia.org/wiki/Chile" wikidataID="Q298"><synonym>CHI</synonym><synonym>cl</synonym><synonym>Republic of Chile</synonym><synonym>Republica de Chile</synonym><synonym>República de Chile</synonym></entry>
# <entry _coords="Point(-102.0 23.0)" _p297_country="MX" description="sovereign state in the southern portion of North America" name="Mexico" term="Mexico" wikidataURL="http://www.wikidata.org/entity/Q96" wikipediaPage="https://en.wikipedia.org/wiki/Mexico" wikipediaURL="https://en.wikipedia.org/wiki/Mexico" wikidataID="Q96"><synonym>MEX</synonym><synonym>Mexican Republic</synonym><synonym>MX</synonym><synonym>mx</synonym><synonym>United Mexican States</synonym></entry>
# <entry _coords="Point(103.8 1.3)" _p297_country="SG" description="sovereign city-state in Southeast Asia" name="Singapore" term="Singapore" wikidataURL="http://www.wikidata.org/entity/Q334" wikipediaPage="https://en.wikipedia.org/wiki/Singapore" wikipediaURL="https://en.wikipedia.org/wiki/Singapore" wikidataID="Q334"><synonym>SG</synonym><synonym>Garden City</synonym><synonym>SGP</synonym><synonym>sg</synonym><synonym>Singapore City</synonym><synonym>Lion City</synonym><synonym>Republic of Singapore</synonym></entry>
# <entry _coords="Point(-8.0 53.0)" _p297_country="IE" description="sovereign state in northwestern Europe covering five-sixths of the island of Ireland" name="Ireland" term="Ireland" wikidataURL="http://www.wikidata.org/entity/Q27" wikipediaPage="https://en.wikipedia.org/wiki/Republic_of_Ireland" wikipediaURL="https://en.wikipedia.org/wiki/Republic_of_Ireland" wikidataID="Q27"><synonym>Southern Ireland</synonym><synonym>Eire</synonym><synonym>Éire</synonym><synonym>IRL</synonym><synonym>Hibernia</synonym><synonym>IE</synonym><synonym>ie</synonym><synonym>ireland</synonym><synonym>Ireland</synonym><synonym>Republic of</synonym><synonym>Republic of Ireland</synonym></entry>
# <entry _coords="Point(1.0 28.0)" _p297_country="DZ" description="sovereign in North Africa" name="Algeria" term="Algeria" wikidataURL="http://www.wikidata.org/entity/Q262" wikipediaPage="https://en.wikipedia.org/wiki/Algeria" wikipediaURL="https://en.wikipedia.org/wiki/Algeria" wikidataID="Q262"><synonym>ALG</synonym><synonym>dz</synonym><synonym>People’s Democratic Republic of Algeria</synonym></entry>
# <entry _coords="Point(136.0 35.0)" _p297_country="JP" description="sovereign state in East Asia, situated on an archipelago of five main and over 6,800 smaller islands" name="Japan" term="Japan" wikidataURL="http://www.wikidata.org/entity/Q17" wikipediaPage="https://en.wikipedia.org/wiki/Japan" wikipediaURL="https://en.wikipedia.org/wiki/Japan" wikidataID="Q17"><synonym>JAP</synonym><synonym>JP</synonym><synonym>jp</synonym><synonym>JA</synonym><synonym>Land of the Rising Sun</synonym><synonym>Nippon</synonym><synonym>JPN</synonym><synonym>Nihon</synonym><synonym>Nihon-koku</synonym><synonym>Nippon-koku</synonym><synonym>State of Japan</synonym></entry>
# <entry _coords="Point(-56.65 -32.733333333)" _p297_country="UY" description="sovereign state in South America" name="Uruguay" term="Uruguay" wikidataURL="http://www.wikidata.org/entity/Q77" wikipediaPage="https://en.wikipedia.org/wiki/Uruguay" wikipediaURL="https://en.wikipedia.org/wiki/Uruguay" wikidataID="Q77"><synonym>República Oriental del Uruguay</synonym><synonym>URU</synonym><synonym>uy</synonym><synonym>Oriental Republic of Uruguay</synonym></entry>
# <entry _coords="Point(9.553889 47.145)" _p297_country="LI" description="sovereign state in western-central Europe" name="Liechtenstein" term="Liechtenstein" wikidataURL="http://www.wikidata.org/entity/Q347" wikipediaPage="https://en.wikipedia.org/wiki/Liechtenstein" wikipediaURL="https://en.wikipedia.org/wiki/Liechtenstein" wikidataID="Q347"><synonym>FL</synonym><synonym>li</synonym><synonym>LI</synonym><synonym>LIE</synonym><synonym>Principality of Liechtenstein</synonym></entry>
# <entry _coords="Point(19.0 47.0)" _p297_country="HU" description="sovereign state in Central Europe" name="Hungary" term="Hungary" wikidataURL="http://www.wikidata.org/entity/Q28" wikipediaPage="https://en.wikipedia.org/wiki/Hungary" wikipediaURL="https://en.wikipedia.org/wiki/Hungary" wikidataID="Q28"><synonym>HUN</synonym><synonym>hu</synonym></entry>
# <entry _coords="Point(38.0 0.1)" _p297_country="KE" description="sovereign state in East Africa" name="Kenya" term="Kenya" wikidataURL="http://www.wikidata.org/entity/Q114" wikipediaPage="https://en.wikipedia.org/wiki/Kenya" wikipediaURL="https://en.wikipedia.org/wiki/Kenya" wikidataID="Q114"><synonym>KE</synonym><synonym>KEN</synonym><synonym>ke</synonym><synonym>Republic of Kenya</synonym></entry>
# <entry _coords="Point(50.551111 26.0675)" _p297_country="BH" description="sovereign state in Southwest Asia" name="Bahrain" term="Bahrain" wikidataURL="http://www.wikidata.org/entity/Q398" wikipediaPage="https://en.wikipedia.org/wiki/Bahrain" wikipediaURL="https://en.wikipedia.org/wiki/Bahrain" wikidataID="Q398"><synonym>BAH</synonym><synonym>bh</synonym><synonym>Kingdom of Bahrain</synonym></entry>
# <entry _coords="Point(-3.5 40.2)" _p297_country="ES" description="sovereign state in southwestern Europe with territories in the Mediterranean Sea, the Atlantic Ocean and northern Africa" name="Spain" term="Spain" wikidataURL="http://www.wikidata.org/entity/Q29" wikipediaPage="https://en.wikipedia.org/wiki/Spain" wikipediaURL="https://en.wikipedia.org/wiki/Spain" wikidataID="Q29"><synonym>ESP</synonym><synonym>España</synonym><synonym>ES</synonym><synonym>Kingdom of Spain</synonym></entry>
# <entry _coords="Point(40.0 9.0)" _p297_country="ET" description="Country in East Africa" name="Ethiopia" term="Ethiopia" wikidataURL="http://www.wikidata.org/entity/Q115" wikipediaPage="https://en.wikipedia.org/wiki/Ethiopia" wikipediaURL="https://en.wikipedia.org/wiki/Ethiopia" wikidataID="Q115"><synonym>et</synonym><synonym>ETH</synonym><synonym>Federal Democratic Republic of Ethiopia</synonym></entry>
# <entry _coords="Point(-0.5 8.0)" _p297_country="GH" description="sovereign state in West Africa" name="Ghana" term="Ghana" wikidataURL="http://www.wikidata.org/entity/Q117" wikipediaPage="https://en.wikipedia.org/wiki/Ghana" wikipediaURL="https://en.wikipedia.org/wiki/Ghana" wikidataID="Q117"><synonym>GHA</synonym><synonym>gh</synonym><synonym>Republic of Ghana</synonym></entry>
# <entry _coords="Point(20.933333333 43.95)" _p297_country="RS" description="sovereign state in southeastern Europe" name="Serbia" term="Serbia" wikidataURL="http://www.wikidata.org/entity/Q403" wikipediaPage="https://en.wikipedia.org/wiki/Serbia" wikipediaURL="https://en.wikipedia.org/wiki/Serbia" wikidataID="Q403"><synonym>SRB</synonym><synonym>rs</synonym><synonym>Republic of Serbia</synonym><synonym>Republika Srbija</synonym><synonym>Srbija</synonym></entry>
# <entry _coords="Point(4.668055555 50.641111111)" _p297_country="BE" description="sovereign state in western Europe" name="Belgium" term="Belgium" wikidataURL="http://www.wikidata.org/entity/Q31" wikipediaPage="https://en.wikipedia.org/wiki/Belgium" wikipediaURL="https://en.wikipedia.org/wiki/Belgium" wikidataID="Q31"><synonym>be</synonym><synonym>BEL</synonym><synonym>Kingdom of Belgium</synonym></entry>
# <entry _coords="Point(-2.0 54.6)" _p297_country="GB" description="sovereign state in western Europe" name="United Kingdom" term="United Kingdom" wikidataURL="http://www.wikidata.org/entity/Q145" wikipediaPage="https://en.wikipedia.org/wiki/United_Kingdom" wikipediaURL="https://en.wikipedia.org/wiki/United_Kingdom" wikidataID="Q145"><synonym>Great Britain</synonym><synonym>G. B.</synonym><synonym>GBR</synonym><synonym>GB</synonym><synonym>UK</synonym><synonym>U.K.</synonym><synonym>United Kingdom of Great Britain and Northern Ireland</synonym><synonym>G.B.</synonym><synonym>Marea Britanie</synonym><synonym>G B</synonym><synonym>U K</synonym><synonym>U. K.</synonym><synonym>G B R</synonym><synonym>G. B. R.</synonym><synonym>G.B.R.</synonym></entry>
# <entry _coords="Point(-76.0 -9.4)" _p297_country="PE" description="sovereign state in South America" name="Peru" term="Peru" wikidataURL="http://www.wikidata.org/entity/Q419" wikipediaPage="https://en.wikipedia.org/wiki/Peru" wikipediaURL="https://en.wikipedia.org/wiki/Peru" wikidataID="Q419"><synonym>pe</synonym><synonym>Republic of Peru</synonym><synonym>Republica del Peru</synonym><synonym>República del Perú</synonym></entry>
# <entry _coords="Point(127.0 40.0)" _p297_country="KP" description="sovereign state in East Asia" name="North Korea" term="North Korea" wikidataURL="http://www.wikidata.org/entity/Q423" wikipediaPage="https://en.wikipedia.org/wiki/North_Korea" wikipediaURL="https://en.wikipedia.org/wiki/North_Korea" wikidataID="Q423"><synonym>kp</synonym><synonym>PRK</synonym><synonym>Dem. Rep. Korea</synonym><synonym>Democratic People's Republic of Korea</synonym><synonym>DPRK</synonym><synonym>N. Korea</synonym></entry>
# <entry _coords="Point(-53.0 -14.0)" _p297_country="BR" description="country in South America" name="Brazil" term="Brazil" wikidataURL="http://www.wikidata.org/entity/Q155" wikipediaPage="https://en.wikipedia.org/wiki/Brazil" wikipediaURL="https://en.wikipedia.org/wiki/Brazil" wikidataID="Q155"><synonym>br</synonym><synonym>BR</synonym><synonym>BRA</synonym><synonym>Brasil</synonym><synonym>Estados Unidos del Brazil</synonym><synonym>Federativa Republica do Brasil</synonym><synonym>Federativa República do Brasil</synonym><synonym>Federative Republic of Brazil</synonym><synonym>Republic Federative of Brasil</synonym><synonym>Republica Federativa do Brasil</synonym><synonym>República Federativa do Brasil</synonym></entry>
# <entry _coords="Point(44.95 40.383333)" _p297_country="AM" description="sovereign state in the South Caucasus region of Eurasia" name="Armenia" term="Armenia" wikidataURL="http://www.wikidata.org/entity/Q399" wikipediaPage="https://en.wikipedia.org/wiki/Armenia" wikipediaURL="https://en.wikipedia.org/wiki/Armenia" wikidataID="Q399"><synonym>ARM</synonym><synonym>Republic of Armenia</synonym></entry>
# <entry _coords="Point(-98.5795 39.828175)" _p297_country="US" description="sovereign state in North America" name="United States of America" term="United States of America" wikidataURL="http://www.wikidata.org/entity/Q30" wikipediaPage="https://en.wikipedia.org/wiki/United_States" wikipediaURL="https://en.wikipedia.org/wiki/United_States" wikidataID="Q30"><synonym>America</synonym><synonym>United States</synonym><synonym>USA</synonym><synonym>US</synonym><synonym>the United States</synonym><synonym>the United States of America</synonym><synonym>the US</synonym><synonym>the USA</synonym><synonym>U.S.</synonym><synonym>U.S.A.</synonym><synonym>US of A</synonym><synonym>U.S</synonym><synonym>U. S.</synonym><synonym>U. S. A.</synonym><synonym>the States</synonym><synonym>the U.S.</synonym><synonym>'Merica</synonym></entry>
# <entry _coords="Point(2.0 47.0)" _p297_country="FR" description="sovereign state with mainland in Europe and several overseas territories" name="France" term="France" wikidataURL="http://www.wikidata.org/entity/Q142" wikipediaPage="https://en.wikipedia.org/wiki/France" wikipediaURL="https://en.wikipedia.org/wiki/France" wikidataID="Q142"><synonym>La France</synonym><synonym>FRA</synonym><synonym>FR</synonym><synonym>French Republic</synonym><synonym>fr</synonym><synonym>Republic of France</synonym><synonym>République française</synonym></entry>
# <entry _coords="Point(137.0 -28.0)" _p297_country="AU" description="island country in the Southern hemisphere" name="Australia" term="Australia" wikidataURL="http://www.wikidata.org/entity/Q408" wikipediaPage="https://en.wikipedia.org/wiki/Australia" wikipediaURL="https://en.wikipedia.org/wiki/Australia" wikidataID="Q408"><synonym>AU</synonym><synonym>au</synonym><synonym>AUS</synonym><synonym>?</synonym><synonym>British Colony of Australia</synonym><synonym>Commonwealth of Australia</synonym><synonym>Straya</synonym><synonym>Aussieland</synonym></entry>
# <entry _coords="Point(6.13 49.77)" _p297_country="LU" description="sovereign state in Central Europe" name="Luxembourg" term="Luxembourg" wikidataURL="http://www.wikidata.org/entity/Q32" wikipediaPage="https://en.wikipedia.org/wiki/Luxembourg" wikipediaURL="https://en.wikipedia.org/wiki/Luxembourg" wikidataID="Q32"><synonym>LU</synonym><synonym>LUX</synonym><synonym>Luxemburg</synonym><synonym>lu</synonym><synonym>Grand Duchy of Luxembourg</synonym></entry>
# <entry _coords="Point(103.451944444 35.844722222)" _p297_country="CN" description="sovereign state in East Asia" name="People's Republic of China" term="People's Republic of China" wikidataURL="http://www.wikidata.org/entity/Q148" wikipediaPage="https://en.wikipedia.org/wiki/China" wikipediaURL="https://en.wikipedia.org/wiki/China" wikidataID="Q148"><synonym>China</synonym><synonym>CHN</synonym><synonym>cn</synonym><synonym>CN</synonym><synonym>Communist China</synonym><synonym>PR China</synonym><synonym>PRC</synonym></entry>
# <entry _coords="Point(-64.0 -34.0)" _p297_country="AR" description="sovereign state in South America" name="Argentina" term="Argentina" wikidataURL="http://www.wikidata.org/entity/Q414" wikipediaPage="https://en.wikipedia.org/wiki/Argentina" wikipediaURL="https://en.wikipedia.org/wiki/Argentina" wikidataID="Q414"><synonym>AR</synonym><synonym>ARG</synonym><synonym>ar</synonym><synonym>Argentine Republic</synonym></entry>
# <entry _coords="Point(15.0 61.0)" _p297_country="SE" description="sovereign state in northern Europe" name="Sweden" term="Sweden" wikidataURL="http://www.wikidata.org/entity/Q34" wikipediaPage="https://en.wikipedia.org/wiki/Sweden" wikipediaURL="https://en.wikipedia.org/wiki/Sweden" wikidataID="Q34"><synonym>se</synonym><synonym>SWE</synonym><synonym>SE</synonym><synonym>Kingdom of Sweden</synonym></entry>
# <entry _coords="Point(27.0 65.0)" _p297_country="FI" description="sovereign state in northern Europe" name="Finland" term="Finland" wikidataURL="http://www.wikidata.org/entity/Q33" wikipediaPage="https://en.wikipedia.org/wiki/Finland" wikipediaURL="https://en.wikipedia.org/wiki/Finland" wikidataID="Q33"><synonym>Suomi</synonym><synonym>FIN</synonym><synonym>fi</synonym><synonym>Finnia</synonym><synonym>Land of Thousand Lakes</synonym><synonym>Republic of Finland</synonym><synonym>Republiken Finland</synonym><synonym>Suomen tasavalta</synonym></entry>
# <entry _coords="Point(24.0 55.2)" _p297_country="LT" description="sovereign state in northeastern Europe" name="Lithuania" term="Lithuania" wikidataURL="http://www.wikidata.org/entity/Q37" wikipediaPage="https://en.wikipedia.org/wiki/Lithuania" wikipediaURL="https://en.wikipedia.org/wiki/Lithuania" wikidataID="Q37"><synonym>LTU</synonym><synonym>lt</synonym><synonym>Lietuva</synonym><synonym>Republic of Lithuania</synonym></entry>
# <entry _coords="Point(28.046666666 53.528333333)" _p297_country="BY" description="sovereign state in eastern Europe" name="Belarus" term="Belarus" wikidataURL="http://www.wikidata.org/entity/Q184" wikipediaPage="https://en.wikipedia.org/wiki/Belarus" wikipediaURL="https://en.wikipedia.org/wiki/Belarus" wikidataID="Q184"><synonym>by</synonym><synonym>White Russia</synonym><synonym>BLR</synonym><synonym>White Ruthenia</synonym><synonym>Byelorussia</synonym><synonym>Belorussia</synonym><synonym>Bielorussia</synonym><synonym>Byeloruss</synonym><synonym>Republic of Belarus</synonym></entry>
# <entry _coords="Point(105.0 12.6)" _p297_country="KH" description="sovereign state in Southeast Asia" name="Cambodia" term="Cambodia" wikidataURL="http://www.wikidata.org/entity/Q424" wikipediaPage="https://en.wikipedia.org/wiki/Cambodia" wikipediaURL="https://en.wikipedia.org/wiki/Cambodia" wikidataID="Q424"><synonym>Camboya</synonym><synonym>Kamboja</synonym><synonym>Kampuchea</synonym><synonym>Campuchia</synonym><synonym>Kambodzha</synonym><synonym>kh</synonym><synonym>Kingdom of Cambodia</synonym></entry>
# <entry _coords="Point(10.0 56.0)" _p297_country="DK" description="sovereign state in northern Europe that is part of the Kingdom of Denmark" name="Denmark" term="Denmark" wikidataURL="http://www.wikidata.org/entity/Q35" wikipediaPage="https://en.wikipedia.org/wiki/Denmark" wikipediaURL="https://en.wikipedia.org/wiki/Denmark" wikidataID="Q35"><synonym>DK</synonym><synonym>Danmark</synonym><synonym>TAN</synonym><synonym>DEN</synonym><synonym>DEK</synonym><synonym>dk</synonym><synonym>DNK</synonym><synonym>Kingdom of Denmark</synonym><synonym>Denmark proper</synonym><synonym>metropolitan Denmark</synonym><synonym>Realm of Denmark</synonym></entry>
# <entry _coords="Point(19.0 52.0)" _p297_country="PL" description="sovereign state in Central Europe" name="Poland" term="Poland" wikidataURL="http://www.wikidata.org/entity/Q36" wikipediaPage="https://en.wikipedia.org/wiki/Poland" wikipediaURL="https://en.wikipedia.org/wiki/Poland" wikidataID="Q36"><synonym>PL</synonym><synonym>POL</synonym><synonym>Republic of Poland</synonym></entry>
# <entry _coords="Point(94.25 66.416666666)" _p297_country="RU" description="sovereign state in Eastern Europe and Northern Asia" name="Russia" term="Russia" wikidataURL="http://www.wikidata.org/entity/Q159" wikipediaPage="https://en.wikipedia.org/wiki/Russia" wikipediaURL="https://en.wikipedia.org/wiki/Russia" wikidataID="Q159"><synonym>RF</synonym><synonym>Rus</synonym><synonym>RU</synonym><synonym>Russian Federation</synonym><synonym>RUS</synonym><synonym>ru</synonym><synonym>Rossiya</synonym><synonym>Rossija</synonym><synonym>Rossijskaja Federatsija</synonym><synonym>Rossiyskaya Federatsiya</synonym></entry>
# <entry _coords="Point(125.75 -8.966667)" _p297_country="TL" description="sovereign state situated on several islands in Southeast Asia" name="East Timor" term="East Timor" wikidataURL="http://www.wikidata.org/entity/Q574" wikipediaPage="https://en.wikipedia.org/wiki/East_Timor" wikipediaURL="https://en.wikipedia.org/wiki/East_Timor" wikidataID="Q574"><synonym>TLS</synonym><synonym>Democratic Republic of East Timor</synonym><synonym>Democratic Republic of Timor-Leste</synonym><synonym>Timor Leste</synonym><synonym>Timor-Leste</synonym><synonym>tl</synonym></entry>
# <entry _coords="Point(10.0 51.0)" _p297_country="DE" description="sovereign state in Central Europe" name="Germany" term="Germany" wikidataURL="http://www.wikidata.org/entity/Q183" wikipediaPage="https://en.wikipedia.org/wiki/Germany" wikipediaURL="https://en.wikipedia.org/wiki/Germany" wikidataID="Q183"><synonym>BRD</synonym><synonym>Bundesrepublik Deutschland</synonym><synonym>de</synonym><synonym>Deutschland</synonym><synonym>Federal Republic of Germany</synonym><synonym>FRG</synonym><synonym>GER</synonym><synonym>BR Deutschland</synonym></entry>
# <entry _coords="Point(19.4 15.466667)" _p297_country="TD" description="sovereign state in central Africa" name="Chad" term="Chad" wikidataURL="http://www.wikidata.org/entity/Q657" wikipediaPage="https://en.wikipedia.org/wiki/Chad" wikipediaURL="https://en.wikipedia.org/wiki/Chad" wikidataID="Q657"><synonym>GUM</synonym><synonym>CHA</synonym><synonym>Republic of Chad</synonym><synonym>td</synonym></entry>
# <entry _coords="Point(174.0 -41.2)" _p297_country="NZ" description="sovereign state in Oceania, situated on two main and around 600 smaller islands in the southwestern Pacific Ocean" name="New Zealand" term="New Zealand" wikidataURL="http://www.wikidata.org/entity/Q664" wikipediaPage="https://en.wikipedia.org/wiki/New_Zealand" wikipediaURL="https://en.wikipedia.org/wiki/New_Zealand" wikidataID="Q664"><synonym>Aotearoa</synonym><synonym>Dominion of New Zealand</synonym><synonym>nz</synonym><synonym>NZ</synonym><synonym>NZL</synonym></entry>
# <entry _coords="Point(12.5 42.5)" _p297_country="IT" description="sovereign state in southern Europe" name="Italy" term="Italy" wikidataURL="http://www.wikidata.org/entity/Q38" wikipediaPage="https://en.wikipedia.org/wiki/Italy" wikipediaURL="https://en.wikipedia.org/wiki/Italy" wikidataID="Q38"><synonym>ITA</synonym><synonym>it</synonym><synonym>IT</synonym><synonym>Italia</synonym><synonym>Italian Republic</synonym></entry>
# <entry _coords="Point(-19.0 65.0)" _p297_country="IS" description="sovereign state in Northern Europe, situated on an island in the far North Atlantic Ocean" name="Iceland" term="Iceland" wikidataURL="http://www.wikidata.org/entity/Q189" wikipediaPage="https://en.wikipedia.org/wiki/Iceland" wikipediaURL="https://en.wikipedia.org/wiki/Iceland" wikidataID="Q189"><synonym>ISL</synonym><synonym>Island</synonym><synonym>is</synonym><synonym>Republic of Iceland</synonym></entry>
# <entry _coords="Point(-172.0 -14.0)" _p297_country="WS" description="sovereign state situated on six islands in the Pacific Ocean" name="Samoa" term="Samoa" wikidataURL="http://www.wikidata.org/entity/Q683" wikipediaPage="https://en.wikipedia.org/wiki/Samoa" wikipediaURL="https://en.wikipedia.org/wiki/Samoa" wikidataID="Q683"><synonym>ws</synonym><synonym>Independent State of Samoa</synonym><synonym>Western Samoa</synonym></entry>
# <entry _coords="Point(36.0 39.0)" _p297_country="TR" description="sovereign state straddling Southeastern Europe and Western Asia" name="Turkey" term="Turkey" wikidataURL="http://www.wikidata.org/entity/Q43" wikipediaPage="https://en.wikipedia.org/wiki/Turkey" wikipediaURL="https://en.wikipedia.org/wiki/Turkey" wikidataID="Q43"><synonym>Republic of Turkey</synonym><synonym>tr</synonym><synonym>TUR</synonym></entry>
# <entry _coords="Point(16.0 50.0)" _p297_country="CZ" description="sovereign state in Central Europe" name="Czech Republic" term="Czech Republic" wikidataURL="http://www.wikidata.org/entity/Q213" wikipediaPage="https://en.wikipedia.org/wiki/Czech_Republic" wikipediaURL="https://en.wikipedia.org/wiki/Czech_Republic" wikidataID="Q213"><synonym>?eská republika</synonym><synonym>?esko</synonym><synonym>?R</synonym><synonym>cz</synonym><synonym>cze</synonym><synonym>CZE</synonym><synonym>Czechia</synonym><synonym>CZR</synonym></entry>
# <entry _coords="Point(14.0 48.0)" _p297_country="AT" description="sovereign state in Central Europe" name="Austria" term="Austria" wikidataURL="http://www.wikidata.org/entity/Q40" wikipediaPage="https://en.wikipedia.org/wiki/Austria" wikipediaURL="https://en.wikipedia.org/wiki/Austria" wikidataID="Q40"><synonym>AT</synonym><synonym>AUT</synonym><synonym>at</synonym><synonym>aut</synonym><synonym>Österreich</synonym><synonym>Republic of Austria</synonym><synonym>Republik Österreich</synonym></entry>
# <entry _coords="Point(25.0 57.0)" _p297_country="LV" description="sovereign state in northeastern Europe" name="Latvia" term="Latvia" wikidataURL="http://www.wikidata.org/entity/Q211" wikipediaPage="https://en.wikipedia.org/wiki/Latvia" wikipediaURL="https://en.wikipedia.org/wiki/Latvia" wikidataID="Q211"><synonym>LAT</synonym><synonym>Latvija</synonym><synonym>LVA</synonym><synonym>lv</synonym><synonym>Latvian Republic</synonym><synonym>Republic of Latvia</synonym></entry>
# <entry _coords="Point(83.0 22.8)" _p297_country="IN" description="sovereign state in South Asia" name="India" term="India" wikidataURL="http://www.wikidata.org/entity/Q668" wikipediaPage="https://en.wikipedia.org/wiki/India" wikipediaURL="https://en.wikipedia.org/wiki/India" wikidataID="Q668"><synonym>IND</synonym><synonym>in</synonym><synonym>Bharat</synonym><synonym>Bharatvarsh</synonym><synonym>Hindustan</synonym><synonym>IN</synonym><synonym>Republic of India</synonym></entry>
# <entry _coords="Point(8.231973 46.798562)" _p297_country="CH" description="federal state in Western Europe" name="Switzerland" term="Switzerland" wikidataURL="http://www.wikidata.org/entity/Q39" wikipediaPage="https://en.wikipedia.org/wiki/Switzerland" wikipediaURL="https://en.wikipedia.org/wiki/Switzerland" wikidataID="Q39"><synonym>Swiss</synonym><synonym>CH</synonym><synonym>CHE</synonym><synonym>Schweiz</synonym><synonym>SUI</synonym><synonym>Swiss Confederation</synonym><synonym>Suisse</synonym><synonym>Confoederatio Helvetica</synonym><synonym>Svizzera</synonym></entry>
# <entry _coords="Point(26.0 59.0)" _p297_country="EE" description="sovereign state in northeastern Europe" name="Estonia" term="Estonia" wikidataURL="http://www.wikidata.org/entity/Q191" wikipediaPage="https://en.wikipedia.org/wiki/Estonia" wikipediaURL="https://en.wikipedia.org/wiki/Estonia" wikidataID="Q191"><synonym>EST</synonym><synonym>Eesti</synonym><synonym>ee</synonym><synonym>Estland</synonym><synonym>Republic of Estonia</synonym></entry>
# <entry _coords="Point(178.005556 -7.475)" _p297_country="TV" description="island sovereign state in Oceania" name="Tuvalu" term="Tuvalu" wikidataURL="http://www.wikidata.org/entity/Q672" wikipediaPage="https://en.wikipedia.org/wiki/Tuvalu" wikipediaURL="https://en.wikipedia.org/wiki/Tuvalu" wikidataID="Q672"><synonym>TUV</synonym><synonym>tv</synonym><synonym>Ellice Islands</synonym></entry>
# <entry _coords="Point(-174.810278 -20.587778)" _p297_country="TO" description="sovereign state in Oceania, situated on an archipelago" name="Tonga" term="Tonga" wikidataURL="http://www.wikidata.org/entity/Q678" wikipediaPage="https://en.wikipedia.org/wiki/Tonga" wikipediaURL="https://en.wikipedia.org/wiki/Tonga" wikidataID="Q678"><synonym>to</synonym><synonym>TGA</synonym><synonym>Kingdom of Tonga</synonym></entry>
# <entry _coords="Point(23.0 38.5)" _p297_country="GR" description="sovereign state in southeastern Europe" name="Greece" term="Greece" wikidataURL="http://www.wikidata.org/entity/Q41" wikipediaPage="https://en.wikipedia.org/wiki/Greece" wikipediaURL="https://en.wikipedia.org/wiki/Greece" wikidataID="Q41"><synonym>el</synonym><synonym>Hellas</synonym><synonym>Hellenic Republic</synonym><synonym>gr</synonym><synonym>GRE</synonym><synonym>Greek Republic</synonym><synonym>Ellada</synonym></entry>
# <entry _coords="Point(32.0 49.0)" _p297_country="UA" description="sovereign state in eastern Europe" name="Ukraine" term="Ukraine" wikidataURL="http://www.wikidata.org/entity/Q212" wikipediaPage="https://en.wikipedia.org/wiki/Ukraine" wikipediaURL="https://en.wikipedia.org/wiki/Ukraine" wikidataID="Q212"><synonym>UKR</synonym><synonym>UA</synonym><synonym>ua</synonym><synonym>Ukrainia</synonym></entry>
# <entry _coords="Point(28.516667 47.25)" _p297_country="MD" description="sovereign state in southeastern Europe" name="Moldova" term="Moldova" wikidataURL="http://www.wikidata.org/entity/Q217" wikipediaPage="https://en.wikipedia.org/wiki/Moldova" wikipediaURL="https://en.wikipedia.org/wiki/Moldova" wikidataID="Q217"><synonym>md</synonym><synonym>MDA</synonym><synonym>Moldavia</synonym><synonym>Republic of Moldova</synonym><synonym>Republica Moldova</synonym></entry>
# <entry _coords="Point(159.816666666 -9.466666666)" _p297_country="SB" description="island sovereign state in Oceania" name="Solomon Islands" term="Solomon Islands" wikidataURL="http://www.wikidata.org/entity/Q685" wikipediaPage="https://en.wikipedia.org/wiki/Solomon_Islands" wikipediaURL="https://en.wikipedia.org/wiki/Solomon_Islands" wikidataID="Q685"><synonym>sb</synonym><synonym>SOL</synonym></entry>
# <entry _coords="Point(-9.183333333 38.7)" _p297_country="PT" description="sovereign state in southwestern Europe" name="Portugal" term="Portugal" wikidataURL="http://www.wikidata.org/entity/Q45" wikipediaPage="https://en.wikipedia.org/wiki/Portugal" wikipediaURL="https://en.wikipedia.org/wiki/Portugal" wikidataID="Q45"><synonym>Portuguese Republic</synonym><synonym>pt</synonym><synonym>PT</synonym></entry>
# <entry _coords="Point(20.0 49.0)" _p297_country="SK" description="sovereign state in Central Europe" name="Slovakia" term="Slovakia" wikidataURL="http://www.wikidata.org/entity/Q214" wikipediaPage="https://en.wikipedia.org/wiki/Slovakia" wikipediaURL="https://en.wikipedia.org/wiki/Slovakia" wikidataID="Q214"><synonym>SVK</synonym><synonym>sk</synonym><synonym>Slovak Republic</synonym></entry>
# <entry _coords="Point(168.016669444 -16.633330555)" _p297_country="VU" description="sovereign state situated on an archipelago in the South Pacific Ocean" name="Vanuatu" term="Vanuatu" wikidataURL="http://www.wikidata.org/entity/Q686" wikipediaPage="https://en.wikipedia.org/wiki/Vanuatu" wikipediaURL="https://en.wikipedia.org/wiki/Vanuatu" wikidataID="Q686"><synonym>Republic of Vanuatu</synonym><synonym>van</synonym><synonym>VAN</synonym><synonym>vu</synonym><synonym>vut</synonym></entry>
# <entry _coords="Point(147.0 -6.3)" _p297_country="PG" description="island sovereign state in Oceania" name="Papua New Guinea" term="Papua New Guinea" wikidataURL="http://www.wikidata.org/entity/Q691" wikipediaPage="https://en.wikipedia.org/wiki/Papua_New_Guinea" wikipediaURL="https://en.wikipedia.org/wiki/Papua_New_Guinea" wikidataID="Q691"><synonym>PNG</synonym><synonym>pg</synonym><synonym>Independent State of Papua New Guinea</synonym></entry>
# <entry _coords="Point(10.0 34.0)" _p297_country="TN" description="sovereign state in Northern Africa" name="Tunisia" term="Tunisia" wikidataURL="http://www.wikidata.org/entity/Q948" wikipediaPage="https://en.wikipedia.org/wiki/Tunisia" wikipediaURL="https://en.wikipedia.org/wiki/Tunisia" wikidataID="Q948"><synonym>Republic of Tunisia</synonym><synonym>tn</synonym><synonym>TUN</synonym><synonym>Tunisian Republic</synonym></entry>
# <entry _coords="Point(15.0 46.0)" _p297_country="SI" description="sovereign state in Central Europe" name="Slovenia" term="Slovenia" wikidataURL="http://www.wikidata.org/entity/Q215" wikipediaPage="https://en.wikipedia.org/wiki/Slovenia" wikipediaURL="https://en.wikipedia.org/wiki/Slovenia" wikidataID="Q215"><synonym>SLO</synonym><synonym>slo</synonym><synonym>si</synonym><synonym>svn</synonym><synonym>Republic of Slovenia</synonym><synonym>Republika Slovenija</synonym><synonym>Slovenija</synonym></entry>
# <entry _coords="Point(104.0 47.0)" _p297_country="MN" description="sovereign state in East Asia" name="Mongolia" term="Mongolia" wikidataURL="http://www.wikidata.org/entity/Q711" wikipediaPage="https://en.wikipedia.org/wiki/Mongolia" wikipediaURL="https://en.wikipedia.org/wiki/Mongolia" wikidataID="Q711"><synonym>MGL</synonym><synonym>MNG</synonym><synonym>mn</synonym><synonym>Mongol uls</synonym></entry>
# <entry _coords="Point(178.0 -18.0)" _p297_country="FJ" description="island sovereign state in Oceania" name="Fiji" term="Fiji" wikidataURL="http://www.wikidata.org/entity/Q712" wikipediaPage="https://en.wikipedia.org/wiki/Fiji" wikipediaURL="https://en.wikipedia.org/wiki/Fiji" wikidataID="Q712"><synonym>fj</synonym><synonym>FIJ</synonym><synonym>Republic of Fiji</synonym><synonym>Republic of the Fiji Islands</synonym></entry>
# <entry _coords="Point(2.183333333 8.833333333)" _p297_country="BJ" description="Country in West Africa" name="Benin" term="Benin" wikidataURL="http://www.wikidata.org/entity/Q962" wikipediaPage="https://en.wikipedia.org/wiki/Benin" wikipediaURL="https://en.wikipedia.org/wiki/Benin" wikidataID="Q962"><synonym>BEN</synonym><synonym>Republic of Benin</synonym><synonym>Dahomey</synonym><synonym>bj</synonym></entry>
# <entry _coords="Point(25.5 42.75)" _p297_country="BG" description="sovereign state in southeastern Europe" name="Bulgaria" term="Bulgaria" wikidataURL="http://www.wikidata.org/entity/Q219" wikipediaPage="https://en.wikipedia.org/wiki/Bulgaria" wikipediaURL="https://en.wikipedia.org/wiki/Bulgaria" wikidataID="Q219"><synonym>bg</synonym><synonym>BUL</synonym><synonym>BGR</synonym><synonym>Republic of Bulgaria</synonym></entry>
# <entry _coords="Point(134.55 7.466667)" _p297_country="PW" description="island sovereign state in Oceania" name="Palau" term="Palau" wikidataURL="http://www.wikidata.org/entity/Q695" wikipediaPage="https://en.wikipedia.org/wiki/Palau" wikipediaURL="https://en.wikipedia.org/wiki/Palau" wikidataID="Q695"><synonym>pw</synonym><synonym>Belau</synonym><synonym>Pelew</synonym><synonym>Republic of Belau</synonym><synonym>Republic of Palau</synonym></entry>
# <entry _coords="Point(166.933333333 -0.533333333)" _p297_country="NR" description="island sovereign state in Oceania" name="Nauru" term="Nauru" wikidataURL="http://www.wikidata.org/entity/Q697" wikipediaPage="https://en.wikipedia.org/wiki/Nauru" wikipediaURL="https://en.wikipedia.org/wiki/Nauru" wikidataID="Q697"><synonym>nr</synonym><synonym>Pleasant Island</synonym><synonym>Naoero</synonym><synonym>Republic of Nauru</synonym></entry>
# <entry _coords="Point(30.0 -19.0)" _p297_country="ZW" description="sovereign state in southern Africa" name="Zimbabwe" term="Zimbabwe" wikidataURL="http://www.wikidata.org/entity/Q954" wikipediaPage="https://en.wikipedia.org/wiki/Zimbabwe" wikipediaURL="https://en.wikipedia.org/wiki/Zimbabwe" wikidataID="Q954"><synonym>Rhodesia</synonym><synonym>ZIM</synonym><synonym>Southern Rhodesia</synonym><synonym>Republic of Zimbabwe</synonym><synonym>Zimbabwe Rhodesia</synonym><synonym>zw</synonym></entry>
# <entry _coords="Point(28.0 -14.0)" _p297_country="ZM" description="sovereign state in Southern Africa" name="Zambia" term="Zambia" wikidataURL="http://www.wikidata.org/entity/Q953" wikipediaPage="https://en.wikipedia.org/wiki/Zambia" wikipediaURL="https://en.wikipedia.org/wiki/Zambia" wikidataID="Q953"><synonym>ZAM</synonym><synonym>Republic of Zambia</synonym><synonym>zm</synonym></entry>
# <entry _coords="Point(25.0 46.0)" _p297_country="RO" description="sovereign state in southeastern Europe" name="Romania" term="Romania" wikidataURL="http://www.wikidata.org/entity/Q218" wikipediaPage="https://en.wikipedia.org/wiki/Romania" wikipediaURL="https://en.wikipedia.org/wiki/Romania" wikidataID="Q218"><synonym>ro</synonym><synonym>Rumania</synonym><synonym>România</synonym><synonym>Roumania</synonym></entry>
# <entry _coords="Point(158.183333333 6.916666666)" _p297_country="FM" description="island sovereign state in Oceania" name="Federated States of Micronesia" term="Federated States of Micronesia" wikidataURL="http://www.wikidata.org/entity/Q702" wikipediaPage="https://en.wikipedia.org/wiki/Federated_States_of_Micronesia" wikipediaURL="https://en.wikipedia.org/wiki/Federated_States_of_Micronesia" wikidataID="Q702"><synonym>FSM</synonym><synonym>Fed. Sts. Micronesia</synonym><synonym>Fed. Sts. of Micronesia</synonym><synonym>Federated States of Micronesia</synonym><synonym>FSM</synonym><synonym>fm</synonym><synonym>Micronesia</synonym></entry>
# <entry _coords="Point(173.033333333 1.466666666)" _p297_country="KI" description="island sovereign state in the central Pacific Ocean" name="Kiribati" term="Kiribati" wikidataURL="http://www.wikidata.org/entity/Q710" wikipediaPage="https://en.wikipedia.org/wiki/Kiribati" wikipediaURL="https://en.wikipedia.org/wiki/Kiribati" wikidataID="Q710"><synonym>KIR</synonym><synonym>ki</synonym><synonym>Republic of Kiribati</synonym></entry>
# <entry _coords="Point(171.066666666 7.116666666)" _p297_country="MH" description="island sovereign state in Oceania" name="Marshall Islands" term="Marshall Islands" wikidataURL="http://www.wikidata.org/entity/Q709" wikipediaPage="https://en.wikipedia.org/wiki/Marshall_Islands" wikipediaURL="https://en.wikipedia.org/wiki/Marshall_Islands" wikidataID="Q709"><synonym>MHL</synonym><synonym>mh</synonym><synonym>Aolep?n Aor?kin M?aje?</synonym><synonym>Republic of the Marshall Islands</synonym></entry>
# <entry _coords="Point(30.0 7.0)" _p297_country="SS" description="sovereign state in Africa" name="South Sudan" term="South Sudan" wikidataURL="http://www.wikidata.org/entity/Q958" wikipediaPage="https://en.wikipedia.org/wiki/South_Sudan" wikipediaURL="https://en.wikipedia.org/wiki/South_Sudan" wikidataID="Q958"><synonym>ss</synonym><synonym>SSD</synonym><synonym>Republic of South Sudan</synonym><synonym>Southern Sudan</synonym></entry>
# <entry _coords="Point(-67.0 8.0)" _p297_country="VE" description="sovereign state in northern South America" name="Venezuela" term="Venezuela" wikidataURL="http://www.wikidata.org/entity/Q717" wikipediaPage="https://en.wikipedia.org/wiki/Venezuela" wikipediaURL="https://en.wikipedia.org/wiki/Venezuela" wikidataID="Q717"><synonym>Bolivarian Republic of Venezuela</synonym><synonym>BR Venezuela</synonym><synonym>Estados Unidos de Venezuela</synonym><synonym>VE</synonym><synonym>VEN</synonym><synonym>Vzla</synonym></entry>
# <entry _coords="Point(23.7 -22.2)" _p297_country="BW" description="sovereign state in Southern Africa" name="Botswana" term="Botswana" wikidataURL="http://www.wikidata.org/entity/Q963" wikipediaPage="https://en.wikipedia.org/wiki/Botswana" wikipediaURL="https://en.wikipedia.org/wiki/Botswana" wikidataID="Q963"><synonym>BOT</synonym><synonym>bw</synonym><synonym>Lefatshe la Botswana</synonym><synonym>Republic of Botswana</synonym></entry>
# <entry _coords="Point(21.716667 41.65)" _p297_country="MK" description="sovereign state in southeastern Europe" name="North Macedonia" term="North Macedonia" wikidataURL="http://www.wikidata.org/entity/Q221" wikipediaPage="https://en.wikipedia.org/wiki/North_Macedonia" wikipediaURL="https://en.wikipedia.org/wiki/North_Macedonia" wikidataID="Q221"><synonym>Macedonia</synonym><synonym>mk</synonym><synonym>Former Yugoslav Republic of Macedonia</synonym><synonym>FYR Macedonia</synonym><synonym>FYROM</synonym><synonym>MKD</synonym><synonym>Republic of Macedonia</synonym><synonym>Republic of North Macedonia</synonym></entry>
# <entry _coords="Point(-56.0 4.0)" _p297_country="SR" description="sovereign state in South America" name="Suriname" term="Suriname" wikidataURL="http://www.wikidata.org/entity/Q730" wikipediaPage="https://en.wikipedia.org/wiki/Suriname" wikipediaURL="https://en.wikipedia.org/wiki/Suriname" wikidataID="Q730"><synonym>Dutch Guiana</synonym><synonym>sr</synonym><synonym>Surinam</synonym><synonym>SUR</synonym><synonym>Republic of Surinam</synonym><synonym>Republic of Suriname</synonym></entry>
# <entry _coords="Point(-2.066667 12.266667)" _p297_country="BF" description="sovereign state in Africa" name="Burkina Faso" term="Burkina Faso" wikidataURL="http://www.wikidata.org/entity/Q965" wikipediaPage="https://en.wikipedia.org/wiki/Burkina_Faso" wikipediaURL="https://en.wikipedia.org/wiki/Burkina_Faso" wikidataID="Q965"><synonym>bf</synonym></entry>
# <entry _coords="Point(20.0 41.0)" _p297_country="AL" description="sovereign state in Southeast Europe" name="Albania" term="Albania" wikidataURL="http://www.wikidata.org/entity/Q222" wikipediaPage="https://en.wikipedia.org/wiki/Albania" wikipediaURL="https://en.wikipedia.org/wiki/Albania" wikidataID="Q222"><synonym>ALB</synonym><synonym>al</synonym><synonym>Republic of Albania</synonym><synonym>Republika e Shqipërisë</synonym><synonym>Shqipërisë</synonym></entry>
# <entry _coords="Point(-40.0 72.0)" _p297_country="GL" description="autonomous country within the Kingdom of Denmark" name="Greenland" term="Greenland" wikidataURL="http://www.wikidata.org/entity/Q223" wikipediaPage="https://en.wikipedia.org/wiki/Greenland" wikipediaURL="https://en.wikipedia.org/wiki/Greenland" wikidataID="Q223"><synonym>gl</synonym></entry>
# <entry _coords="Point(-58.0 -23.5)" _p297_country="PY" description="sovereign state in South America" name="Paraguay" term="Paraguay" wikidataURL="http://www.wikidata.org/entity/Q733" wikipediaPage="https://en.wikipedia.org/wiki/Paraguay" wikipediaURL="https://en.wikipedia.org/wiki/Paraguay" wikidataID="Q733"><synonym>py</synonym><synonym>Heart of South America</synonym><synonym>Republic of Paraguay</synonym></entry>
# <entry _coords="Point(29.816667 -3.666667)" _p297_country="BI" description="sovereign state in Africa" name="Burundi" term="Burundi" wikidataURL="http://www.wikidata.org/entity/Q967" wikipediaPage="https://en.wikipedia.org/wiki/Burundi" wikipediaURL="https://en.wikipedia.org/wiki/Burundi" wikidataID="Q967"><synonym>bi</synonym><synonym>BDI</synonym><synonym>Gouvernement du Burundi</synonym><synonym>Republic of Burundi</synonym><synonym>Republika y'Uburundi</synonym></entry>
# <entry _coords="Point(15.466667 45.25)" _p297_country="HR" description="sovereign state in Central Europe" name="Croatia" term="Croatia" wikidataURL="http://www.wikidata.org/entity/Q224" wikipediaPage="https://en.wikipedia.org/wiki/Croatia" wikipediaURL="https://en.wikipedia.org/wiki/Croatia" wikidataID="Q224"><synonym>hr</synonym><synonym>CRO</synonym><synonym>HRV</synonym><synonym>HR</synonym><synonym>Republic of Croatia</synonym></entry>
# <entry _coords="Point(-59.316667 5.733333)" _p297_country="GY" description="sovereign state in South America" name="Guyana" term="Guyana" wikidataURL="http://www.wikidata.org/entity/Q734" wikipediaPage="https://en.wikipedia.org/wiki/Guyana" wikipediaURL="https://en.wikipedia.org/wiki/Guyana" wikidataID="Q734"><synonym>Co-operative Republic of Guyana</synonym><synonym>GUY</synonym><synonym>gy</synonym><synonym>Republic of Guyana</synonym></entry>
# <entry _coords="Point(-78.0 -1.0)" _p297_country="EC" description="sovereign state in South America" name="Ecuador" term="Ecuador" wikidataURL="http://www.wikidata.org/entity/Q736" wikipediaPage="https://en.wikipedia.org/wiki/Ecuador" wikipediaURL="https://en.wikipedia.org/wiki/Ecuador" wikidataID="Q736"><synonym>ECU</synonym><synonym>EC</synonym><synonym>ecu</synonym><synonym>ec</synonym><synonym>Republic of Ecuador</synonym><synonym>Republic of the Equator</synonym><synonym>The Ecuadorian State</synonym></entry>
# <entry _coords="Point(44.233333 -12.183333)" _p297_country="KM" description="sovereign state situated on an archipelago in the Indian Ocean off the eastern coast of Africa" name="Comoros" term="Comoros" wikidataURL="http://www.wikidata.org/entity/Q970" wikipediaPage="https://en.wikipedia.org/wiki/Comoros" wikipediaURL="https://en.wikipedia.org/wiki/Comoros" wikidataID="Q970"><synonym>COM</synonym><synonym>km</synonym><synonym>al-Itti??d al-Qumur?</synonym><synonym>Juzur al-Qamar</synonym><synonym>Juzur al-Qumur</synonym><synonym>Massiwa ya komori</synonym><synonym>ouvoimoja wakomori</synonym><synonym>Udzima wa Komori</synonym><synonym>Union des Comores</synonym><synonym>Union of the Comoros</synonym></entry>
# ...
# <entry _coords="Point(-64.75 32.333333)" _p297_country="BM" description="British overseas territory in the North Atlantic Ocean" name="Bermuda" term="Bermuda" wikidataURL="http://www.wikidata.org/entity/Q23635" wikipediaPage="https://en.wikipedia.org/wiki/Bermuda" wikipediaURL="https://en.wikipedia.org/wiki/Bermuda" wikidataID="Q23635"><synonym>bm</synonym><synonym>Bermuda Islands</synonym><synonym>Atlantic/Bermuda</synonym><synonym>Bermoothes</synonym><synonym>Bermudas</synonym><synonym>Bermudian Islands</synonym><synonym>Colony of Bermuda</synonym><synonym>Devil's Isles</synonym><synonym>Isle of Devils</synonym><synonym>Somers Islands</synonym><synonym>Somers Isles</synonym><synonym>Summer's Isles</synonym><synonym>Summers' Isles</synonym><synonym>Territory of Bermuda</synonym><synonym>The Somers Isles</synonym><synonym>Virgineola</synonym></entry>
# <entry _coords="Point(-64.75167 32.30444)" _p297_country="BM" description="British overseas territory in the North Atlantic Ocean" name="Bermuda" term="Bermuda" wikidataURL="http://www.wikidata.org/entity/Q23635" wikipediaPage="https://en.wikipedia.org/wiki/Bermuda" wikipediaURL="https://en.wikipedia.org/wiki/Bermuda" wikidataID="Q23635"><synonym>bm</synonym><synonym>Bermuda Islands</synonym><synonym>Atlantic/Bermuda</synonym><synonym>Bermoothes</synonym><synonym>Bermudas</synonym><synonym>Bermudian Islands</synonym><synonym>Colony of Bermuda</synonym><synonym>Devil's Isles</synonym><synonym>Isle of Devils</synonym><synonym>Somers Islands</synonym><synonym>Somers Isles</synonym><synonym>Summer's Isles</synonym><synonym>Summers' Isles</synonym><synonym>Territory of Bermuda</synonym><synonym>The Somers Isles</synonym><synonym>Virgineola</synonym></entry>
# <entry _coords="Point(-2.583333333 49.45)" _p297_country="GG" description="British Crown dependency comprised of several islands" name="Guernsey" term="Guernsey" wikidataURL="http://www.wikidata.org/entity/Q25230" wikipediaPage="https://en.wikipedia.org/wiki/Bailiwick_of_Guernsey" wikipediaURL="https://en.wikipedia.org/wiki/Bailiwick_of_Guernsey" wikidataID="Q25230"><synonym>GBG</synonym><synonym>gg</synonym><synonym>GGY</synonym><synonym>Bailiwick of Guernsey</synonym><synonym>Bailliage de Guernesey</synonym><synonym>GB-GSY</synonym><synonym>Great Britain Guernsey</synonym><synonym>Lisia</synonym><synonym>XA-GG</synonym></entry>
# <entry _coords="Point(-63.048888888 18.227222222)" _p297_country="AI" description="British Overseas Territory in the Caribbean" name="Anguilla" term="Anguilla" wikidataURL="http://www.wikidata.org/entity/Q25228" wikipediaPage="https://en.wikipedia.org/wiki/Anguilla" wikipediaURL="https://en.wikipedia.org/wiki/Anguilla" wikidataID="Q25228"><synonym>ai</synonym></entry>
# <entry _coords="Point(-68.966666666 12.166666666)" _p297_country="CW" description="island country in the Caribbean, part of the Kingdom of the Netherlands" name="Curaçao" term="Curaçao" wikidataURL="http://www.wikidata.org/entity/Q25279" wikipediaPage="https://en.wikipedia.org/wiki/Cura%C3%A7ao" wikipediaURL="https://en.wikipedia.org/wiki/Cura%C3%A7ao" wikidataID="Q25279"><synonym>CW</synonym><synonym>Curacao</synonym><synonym>Country of Curaçao</synonym><synonym>Curacau</synonym><synonym>Curaçoa</synonym><synonym>Curazao</synonym><synonym>Cura?ao</synonym><synonym>Curocao</synonym><synonym>CUW</synonym><synonym>Island Territory of Curaçao</synonym><synonym>ISO 3166-1:CW</synonym><synonym>Korsou</synonym><synonym>Kòrsou</synonym></entry>
# <entry _coords="Point(-63.06 18.075277777)" _p297_country="MF" description="French overseas collectivity, part of the island of Saint Martin in the Lesser Antilles" name="Saint Martin (French part)" term="Saint Martin (French part)" wikidataURL="http://www.wikidata.org/entity/Q126125" wikipediaPage="https://en.wikipedia.org/wiki/Collectivity_of_Saint_Martin" wikipediaURL="https://en.wikipedia.org/wiki/Collectivity_of_Saint_Martin" wikidataID="Q126125"><synonym>St. Martin</synonym><synonym>MF</synonym><synonym>St Martin</synonym><synonym>mf</synonym><synonym>Collectivity of Saint Martin</synonym><synonym>FR-MF</synonym><synonym>Saint Martin (France)</synonym><synonym>St. Martin (French part)</synonym></entry>
# <entry _coords="Point(20.9 6.7)" _p297_country="CF" description="sovereign state in Africa" name="Central African Republic" term="Central African Republic" wikidataURL="http://www.wikidata.org/entity/Q929" wikipediaPage="https://en.wikipedia.org/wiki/Central_African_Republic" wikipediaURL="https://en.wikipedia.org/wiki/Central_African_Republic" wikidataID="Q929"><synonym>CAF</synonym><synonym>CAR</synonym><synonym>Centrafrique</synonym><synonym>cf</synonym><synonym>Ködörösêse tî Bêafrîka</synonym><synonym>Republique centrafricaine</synonym><synonym>République centrafricaine</synonym></entry>
# <entry _coords="Point(1.183333 8.25)" _p297_country="TG" description="sovereign state in Africa" name="Togo" term="Togo" wikidataURL="http://www.wikidata.org/entity/Q945" wikipediaPage="https://en.wikipedia.org/wiki/Togo" wikipediaURL="https://en.wikipedia.org/wiki/Togo" wikidataID="Q945"><synonym>TOG</synonym><synonym>tg</synonym><synonym>Togolese Republic</synonym></entry>
# <entry _coords="Point(-64.5 18.5)" _p297_country="VG" description="British overseas territory in the Caribbean" name="British Virgin Islands" term="British Virgin Islands" wikidataURL="http://www.wikidata.org/entity/Q25305" wikipediaPage="https://en.wikipedia.org/wiki/British_Virgin_Islands" wikipediaURL="https://en.wikipedia.org/wiki/British_Virgin_Islands" wikidataID="Q25305"><synonym>BVI</synonym><synonym>Virgin Islands</synonym><synonym>IVB</synonym><synonym>vg</synonym></entry>
# <entry _coords="Point(-62.8342438 17.897728)" _p297_country="BL" description="overseas collectivity of France, island of the Little Antillas" name="Saint Barthélemy" term="Saint Barthélemy" wikidataURL="http://www.wikidata.org/entity/Q25362" wikipediaPage="https://en.wikipedia.org/wiki/Saint_Barth%C3%A9lemy" wikipediaURL="https://en.wikipedia.org/wiki/Saint_Barth%C3%A9lemy" wikidataID="Q25362"><synonym>bl</synonym><synonym>America/St Barthelemy</synonym><synonym>Collectivite de Saint-Barthelemy</synonym><synonym>Collectivité de Saint-Barthélemy</synonym><synonym>Collectivity of Saint Barthelemy</synonym><synonym>Collectivity of Saint Barthélemy</synonym><synonym>FR-BL</synonym><synonym>Ile Saint-Barthelemy</synonym><synonym>Ile Saint-Barthélemy</synonym><synonym>Île Saint-Barthélemy</synonym><synonym>ISO 3166-1:BL</synonym><synonym>Ouanalao</synonym><synonym>Saint Barth</synonym><synonym>Saint Barthelemy</synonym><synonym>Saint Barthélémy</synonym><synonym>Saint Barths</synonym><synonym>Saint Barts</synonym><synonym>Saint Bartz</synonym><synonym>Saint-Barthelemy</synonym><synonym>Saint-Barthélémy</synonym><synonym>St barthelemy</synonym><synonym>St barths</synonym><synonym>St barts</synonym><synonym>St. Barth</synonym><synonym>St. Barthelemy</synonym><synonym>St. Barthélemy</synonym><synonym>St. Barths</synonym><synonym>St. Barts</synonym></entry>
# <entry _coords="Point(-63.067777777 18.031944444)" _p297_country="SX" description="country on the Caribbean island of Saint Martin, part of the Kingdom of the Netherlands" name="Sint Maarten" term="Sint Maarten" wikidataURL="http://www.wikidata.org/entity/Q26273" wikipediaPage="https://en.wikipedia.org/wiki/Sint_Maarten" wikipediaURL="https://en.wikipedia.org/wiki/Sint_Maarten" wikidataID="Q26273"><synonym>Saint Martin</synonym><synonym>SX</synonym><synonym>St Martin</synonym><synonym>NL-SX</synonym><synonym>Saint Martin (Dutch part)</synonym><synonym>Sint Maarten (Dutch part)</synonym><synonym>St. Maarten</synonym></entry>
# <entry _coords="Point(69.167 -49.25)" _p297_country="TF" description="overseas territory of France" name="French Southern and Antarctic Lands" term="French Southern and Antarctic Lands" wikidataURL="http://www.wikidata.org/entity/Q129003" wikipediaPage="https://en.wikipedia.org/wiki/French_Southern_and_Antarctic_Lands" wikipediaURL="https://en.wikipedia.org/wiki/French_Southern_and_Antarctic_Lands" wikidataID="Q129003"><synonym>tf</synonym><synonym>French Southern Territories</synonym></entry>
# <entry _coords="Point(73.516992 -53.09354)" _p297_country="HM" description="Australian external territory and volcanic group of barren Antarctic islands" name="Heard Island and McDonald Islands" term="Heard Island and McDonald Islands" wikidataURL="http://www.wikidata.org/entity/Q131198" wikipediaPage="https://en.wikipedia.org/wiki/Heard_Island_and_McDonald_Islands" wikipediaURL="https://en.wikipedia.org/wiki/Heard_Island_and_McDonald_Islands" wikidataID="Q131198"><synonym>hm</synonym><synonym>Heard and McDonald Islands</synonym><synonym>HIMI</synonym><synonym>Territory of Heard Island and McDonald Islands</synonym></entry>
# <entry _coords="Point(-5.7181 -15.9245)" _p297_country="SH" description="British overseas territory in the southern Atlantic Ocean" name="Saint Helena, Ascension and Tristan da Cunha" term="Saint Helena, Ascension and Tristan da Cunha" wikidataURL="http://www.wikidata.org/entity/Q192184" wikipediaPage="https://en.wikipedia.org/wiki/Saint_Helena,_Ascension_and_Tristan_da_Cunha" wikipediaURL="https://en.wikipedia.org/wiki/Saint_Helena,_Ascension_and_Tristan_da_Cunha" wikidataID="Q192184"><synonym>SH</synonym><synonym>Saint Helena and Dependencies</synonym></entry>
# <entry _coords="Point(35.25 32.0)" _p297_country="PS" description="de jure sovereign state in the Middle East, recognized as such by several countries and international organizations, and as an observer member in the United Nations and for most other countries" name="State of Palestine" term="State of Palestine" wikidataURL="http://www.wikidata.org/entity/Q219060" wikipediaPage="https://en.wikipedia.org/wiki/State_of_Palestine" wikipediaURL="https://en.wikipedia.org/wiki/State_of_Palestine" wikidataID="Q219060"><synonym>Palestine</synonym><synonym>Palestinian Authority</synonym><synonym>Palestinian National Authority</synonym><synonym>Palestinian state</synonym></entry>
# <entry _coords="Point(10.0 56.0)" _p297_country="DK" description="sovereign unitary state in Northern Europe, the Arctic and the North Atlantic" name="Kingdom of Denmark" term="Kingdom of Denmark" wikidataURL="http://www.wikidata.org/entity/Q756617" wikipediaPage="https://en.wikipedia.org/wiki/Kingdom_of_Denmark" wikipediaURL="https://en.wikipedia.org/wiki/Kingdom_of_Denmark" wikidataID="Q756617"><synonym>DK</synonym><synonym>Denmark</synonym><synonym>Danish Realm</synonym><synonym>the Realm of Denmark</synonym><synonym>Realm of Denmark</synonym></entry>
# <entry _coords="Point(-40.0 72.0)" _p297_country="DK" description="sovereign unitary state in Northern Europe, the Arctic and the North Atlantic" name="Kingdom of Denmark" term="Kingdom of Denmark" wikidataURL="http://www.wikidata.org/entity/Q756617" wikipediaPage="https://en.wikipedia.org/wiki/Kingdom_of_Denmark" wikipediaURL="https://en.wikipedia.org/wiki/Kingdom_of_Denmark" wikidataID="Q756617"><synonym>DK</synonym><synonym>Denmark</synonym><synonym>Danish Realm</synonym><synonym>the Realm of Denmark</synonym><synonym>Realm of Denmark</synonym></entry>
# <entry _coords="Point(-6.844444444 61.97)" _p297_country="DK" description="sovereign unitary state in Northern Europe, the Arctic and the North Atlantic" name="Kingdom of Denmark" term="Kingdom of Denmark" wikidataURL="http://www.wikidata.org/entity/Q756617" wikipediaPage="https://en.wikipedia.org/wiki/Kingdom_of_Denmark" wikipediaURL="https://en.wikipedia.org/wiki/Kingdom_of_Denmark" wikidataID="Q756617"><synonym>DK</synonym><synonym>Denmark</synonym><synonym>Danish Realm</synonym><synonym>the Realm of Denmark</synonym><synonym>Realm of Denmark</synonym></entry>
# <entry _coords="Point(-159.783333333 -21.233333333)" _p297_country="CK" description="state in the South Pacific Ocean" name="Cook Islands" term="Cook Islands" wikidataURL="http://www.wikidata.org/entity/Q26988" wikipediaPage="https://en.wikipedia.org/wiki/Cook_Islands" wikipediaURL="https://en.wikipedia.org/wiki/Cook_Islands" wikidataID="Q26988"><synonym>COK</synonym><synonym>ck</synonym></entry>
# <entry _coords="Point(-68.233333333 12.183333333)" _p297_country="BQ" description="grouping of the Caribbean islands of Bonaire, Sint Eustatius, and Saba, part of the Netherlands" name="Caribbean Netherlands" term="Caribbean Netherlands" wikidataURL="http://www.wikidata.org/entity/Q27561" wikipediaPage="https://en.wikipedia.org/wiki/Caribbean_Netherlands" wikipediaURL="https://en.wikipedia.org/wiki/Caribbean_Netherlands" wikidataID="Q27561"><synonym>BES islands</synonym></entry>
# <entry _coords="Point(4.883333333 52.366666666)" _p297_country="NL" description="sovereign state in Western Europe and the Caribbean" name="Kingdom of the Netherlands" term="Kingdom of the Netherlands" wikidataURL="http://www.wikidata.org/entity/Q29999" wikipediaPage="https://en.wikipedia.org/wiki/Kingdom_of_the_Netherlands" wikipediaURL="https://en.wikipedia.org/wiki/Kingdom_of_the_Netherlands" wikidataID="Q29999"><synonym>NL</synonym><synonym>Netherlands</synonym><synonym>the Netherlands</synonym></entry>
# <entry _coords="Point(-149.566666666 -17.533333333)" _p297_country="PF" description="French overseas country in the Southern Pacific ocean" name="French Polynesia" term="French Polynesia" wikidataURL="http://www.wikidata.org/entity/Q30971" wikipediaPage="https://en.wikipedia.org/wiki/French_Polynesia" wikipediaURL="https://en.wikipedia.org/wiki/French_Polynesia" wikidataID="Q30971"><synonym>pf</synonym></entry>
# <entry _coords="Point(0.0 -90.0)" _p297_country="AQ" description="area around the South Pole covered by the Antarctic Treaty" name="Antarctic Treaty area" term="Antarctic Treaty area" wikidataURL="http://www.wikidata.org/entity/Q21590062" wikidataID="Q21590062"><synonym>ATA</synonym><synonym>AQ</synonym><synonym>Antarctica treaty area</synonym></entry>
# Version: amidict 2020.08.09_09.54-NEXT-SNAPSHOT
# (jar:file:/C:/Users/eless/ami3/target/appassembler/repo/ami3-2020.08.09_09.54-NEXT-SNAPSHOT.jar)
# JVM: 14.0.1 (Oracle Corporation Java HotSpot(TM) 64-Bit Server VM 14.0.1+7)
# OS: Windows 10 10.0 amd64
#
# dictionaryName: country
# sparqlVariables [wikidata, wikidataLabel, wikipedia, alt, synonym, term, wikidataDescription, _iso3166, coords]
# sparqlNameByAmiName: {_p297_country=_iso3166, wikidataID=wikidata, name=wikidataLabel, description=wikidataDescription, term=wikidataLabel, wikidataURL=wikidata, wikipediaPage=wikipedia, _coords=coords, wikipediaURL=wikipedia}
# amiNames [_p297_country, wikidataID, name, description, term, wikidataURL, wikipediaPage, _coords, wikipediaURL]
# WS>[_p297_country, wikidataID, name, description, term, wikidataURL, wikipediaPage, _coords, wikipediaURL]
# Personal ami name: _coords
# Personal ami name: _p297_country
# [_coords, _p297_country, description, name, term, wikidataID, wikidataURL, wikipediaPage, wikipediaURL]
# search: [_iso3166, wikidata, wikidataLabel, wikidataDescription, wikidataLabel, wikidata, wikipedia, coords, wikipedia]
# target: [wikidata, wikidataLabel, wikipedia, alt, synonym, term, wikidataDescription, _iso3166, coords]
# search: [wikidata, wikidataLabel, wikipedia, alt, synonym, term, wikidataDescription, _iso3166, coords]
# target: [_iso3166, wikidata, wikidataLabel, wikidataDescription, wikidataLabel, wikidata, wikipedia, coords, wikipedia, synonym]
# alt not found in amiValues
# term not found in amiValues
# sparql names [wikidata, wikidataLabel, wikipedia, alt, synonym, term, wikidataDescription, _iso3166, coords]
# results 256
# dicc> cannot find binding: wikipedia
# dicc> cannot find binding: wikipedia
# FIX OUTPUT
# writing dictionary to C:\Users\eless\Documents\viral_epidemic_country\dictionary\country.xml

# %% [markdown]
# ##### The Results should look like this

# %% [raw]
# Version: amidict 2020.08.09_09.54-NEXT-SNAPSHOT
# (jar:file:/C:/Users/eless/ami3/target/appassembler/repo/ami3-2020.08.09_09.54-NEXT-SNAPSHOT.jar)
# JVM: 14.0.1 (Oracle Corporation Java HotSpot(TM) 64-Bit Server VM 14.0.1+7)
# OS: Windows 10 10.0 amd64
#
# ....
# ....
# <entry _p297_country="DK" description="sovereign unitary state in Northern Europe, the Arctic and the North Atlantic" name="Kingdom of Denmark" term="Kingdom of Denmark" wikidataURL="http://www.wikidata.org/entity/Q756617" wikipediaPage="https://en.wikipedia.org/wiki/Kingdom_of_Denmark" wikipediaURL="https://en.wikipedia.org/wiki/Kingdom_of_Denmark" wikidataID="Q756617"><synonym>DK</synonym><synonym>Denmark</synonym><synonym>Danish Realm</synonym><synonym>the Realm of Denmark</synonym><synonym>Realm of Denmark</synonym></entry>
# <entry _p297_country="SJ" description="two parts of Norway under separate jurisdictions" name="Svalbard and Jan Mayen" term="Svalbard and Jan Mayen" wikidataURL="http://www.wikidata.org/entity/Q842829" wikipediaPage="https://en.wikipedia.org/wiki/Svalbard_and_Jan_Mayen" wikipediaURL="https://en.wikipedia.org/wiki/Svalbard_and_Jan_Mayen" wikidataID="Q842829"><synonym>sj</synonym></entry>
# <entry _p297_country="AQ" description="area around the South Pole covered by the Antarctic Treaty" name="Antarctic Treaty area" term="Antarctic Treaty area" wikidataURL="http://www.wikidata.org/entity/Q21590062" wikidataID="Q21590062"><synonym>ATA</synonym><synonym>AQ</synonym><synonym>Antarctica treaty area</synonym></entry>
# writing dictionary to C:\Users\eless\Documents\viral_epidemic_country\dictionary\country.xml

# %% [markdown]
# #### The dictionary is then validated using amidict

# %%
# !amidict --dictionary country --directory dictionary display --validate
# Out:
# Generic values (DictionaryDisplayTool)
# ================================
# -v to see generic values
#
# Specific values (DictionaryDisplayTool)
# ================================
# --testString        : d      null
# --wikilinks         : d [Lorg.contentmine.ami.tools.AbstractAMIDictTool$WikiLink;@13d9b21f
# --fields            : d        []
# --files             : d        []
# --maxEntries        : d         3
# --remote            : d [https://github.com/petermr/dictionary]
# --suffix            : d       xml
# --validate          : m      true
# --help              : d     false
# --version           : d     false
# --dictionary        : d [country]
# --directory         : d dictionary
#     Netherlands
#     South Africa
#     Canada
#     ....

# %% [markdown]
# ##### The results should look like this:

# %% [raw]
# Generic values (DictionaryDisplayTool)
# ================================
# -v to see generic values
#
# Specific values (DictionaryDisplayTool)
# ================================
# --testString        : d      null
# --wikilinks         : d [Lorg.contentmine.ami.tools.AbstractAMIDictTool$WikiLink;@2da59753
# --fields            : d        []
# --files             : d        []
# --maxEntries        : d         3
# --remote            : d [https://github.com/petermr/dictionary]
# --suffix            : d       xml
# --validate          : m      true
# --help              : d     false
# --version           : d     false
# --dictionary        : d [country]
# --directory         : d dictionary
#     Canada
#     Netherlands
#     South Africa
#     ....
